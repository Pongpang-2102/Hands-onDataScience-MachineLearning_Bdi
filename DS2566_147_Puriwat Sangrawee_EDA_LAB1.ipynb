# %% [markdown]
# #Exploratory Data Analysis

# %%
# import package library
import numpy as np
import pandas as pd
# some imports to set up plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ในกรณีที่ใช้ Matplotlib บน Jupyther Notebook หรือ Google Colab อาจจะต้องมีการเพิ่ม Code ด้านล่างลงไปเพื่อให้สามารถแสดงได้ โดยที่ไม่ต้องใช้คำสั่ง plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# ในกรณีใช้ IDE อื่นที่ไม่ใช่ Jupyther Notebook หรือ Google Colab ต้องเพิ่ม plt.show() เมื่อต้องการวาดกราฟออกมาทางหน้าจอ

# %% [markdown]
# # 1) นำเข้าข้อมูล
# อ่านไฟล์ข้อมูล "churn_telecom.csv"

# %%
df=pd.read_csv('churn_telecom.csv')

# %%
#ดูตัวอย่างข้อมูล 5 แถวแรก
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
# 2             56.59              317.8               97             27.01
# 3             18.77              137.3              102             11.67
# 4             20.28              215.1              109             18.28
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
# 2                160.6                128                7.23
# 3                189.6                105                8.53
# 4                178.7                 90                8.04
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# 1                12.7                 6               3.43
# 2                 5.4                 9               1.46
# 3                 7.7                 6               2.08
# 4                11.1                 1               3.00
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       4   True
# 2                       4   True
# 3                       2  False
# 4                       1  False

# %%
#ดูข้อมูล 10 แถวสุดท้าย
df.tail(10)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 657    AZ              48        415                 No             Yes
# 658    KS              57        415                 No              No
# 659    CA             127        510                 No              No
# 660    IN             114        408                 No              No
# 661    CA              84        415                 No              No
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 657                     27              141.1              109
# 658                      0              158.1              117
# 659                      0              107.9              128
# 660                      0              203.8               85
# 661                      0              280.0              113
# 662                     26              137.1               88
# 663                     29               83.6              131
# 664                      0              193.9              118
# 665                      0              169.8              114
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 657             23.99              224.7               94             19.10
# 658             26.88              115.2              149              9.79
# 659             18.34              187.0               77             15.90
# 660             34.65               87.8              110              7.46
# 661             47.60              202.2               90             17.19
# 662             23.31              155.7              125             13.23
# 663             14.21              203.9              131             17.33
# 664             32.96               85.0              110              7.23
# 665             28.87              197.7              105             16.80
# 666             36.35              159.6               84             13.57
#
#      Total night minutes  Total night calls  Total night charge  \
# 657                174.3                122                7.84
# 658                182.4                 92                8.21
# 659                218.5                 95                9.83
# 660                166.2                122                7.48
# 661                156.8                103                7.06
# 662                247.6                 94               11.14
# 663                229.5                 73               10.33
# 664                210.1                134                9.45
# 665                193.7                 82                8.72
# 666                139.2                137                6.26
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 657                13.2                 2               3.56
# 658                11.8                 7               3.19
# 659                 0.0                 0               0.00
# 660                11.7                 4               3.16
# 661                10.4                 4               2.81
# 662                11.5                 7               3.11
# 663                 8.1                 3               2.19
# 664                13.2                 8               3.56
# 665                11.6                 4               3.13
# 666                 5.0                10               1.35
#
#      Customer service calls  Churn
# 657                       1  False
# 658                       0  False
# 659                       0  False
# 660                       1  False
# 661                       0   True
# 662                       2  False
# 663                       1  False
# 664                       3  False
# 665                       1  False
# 666                       2  False

# %%
#สุ่มข้อมูลมา 3 แถว
df.sample(3)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 363    MN              85        415                 No              No
# 76     NV              64        415                 No              No
# 154    WV             115        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 363                      0              255.3              114
# 76                       0               97.2               80
# 154                      0              249.9               95
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 363             43.40              194.6               83             16.54
# 76              16.52              186.2               90             15.83
# 154             42.48              242.5              104             20.61
#
#      Total night minutes  Total night calls  Total night charge  \
# 363                276.6                 78               12.45
# 76                 189.0                 92                8.50
# 154                151.7                121                6.83
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 363                 3.7                 5               1.00
# 76                 10.4                 6               2.81
# 154                15.3                 6               4.13
#
#      Customer service calls  Churn
# 363                       3  False
# 76                        2  False
# 154                       1   True

# %% [markdown]
# #2) สำรวจข้อมูล

# %%
#ดูรายละเอียดข้อมูล
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
#  14  Total night charge      667 non-null    float64
#  15  Total intl minutes      667 non-null    float64
#  16  Total intl calls        667 non-null    int64
#  17  Total intl charge       667 non-null    float64
#  18  Customer service calls  667 non-null    int64
#  19  Churn                   667 non-null    bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 99.8+ KB

# %%
#เรียกดูชื่อคอลัมน์
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#ดูชนิดข้อมูล
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
#ดูค่าทางสถิติพื้นฐาน
df.describe()
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# std          20.396790          9.436463          49.719268        18.948262
# min          30.000000          4.400000          48.100000        37.000000
# 25%          87.500000         24.860000         171.050000        88.000000
# 50%         101.000000         30.310000         203.700000       101.000000
# 75%         115.000000         37.520000         236.450000       113.000000
# max         165.000000         56.830000         361.800000       168.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count        667.000000           667.000000         667.000000
# mean          17.285262           199.685307         100.113943
# std            4.226160            49.759931          20.172505
# min            4.090000            23.200000          42.000000
# 25%           14.540000           167.950000          86.000000
# 50%           17.310000           201.600000         100.000000
# 75%           20.095000           231.500000         113.500000
# max           30.750000           367.700000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count          667.000000          667.000000        667.000000
# mean             8.985907           10.238381          4.527736
# std              2.239429            2.807850          2.482442
# min              1.040000            0.000000          0.000000
# 25%              7.560000            8.600000          3.000000
# 50%              9.070000           10.500000          4.000000
# 75%             10.420000           12.050000          6.000000
# max             16.550000           18.300000         18.000000
#
#        Total intl charge  Customer service calls
# count         667.000000              667.000000
# mean            2.764948                1.563718
# std             0.758167                1.333357
# min             0.000000                0.000000
# 25%             2.320000                1.000000
# 50%             2.840000                1.000000
# 75%             3.255000                2.000000
# max             4.940000                8.000000

# %%
#ดูค่าทางสถิติพื้นฐานสำหรับข้อมูลที่เป็น object และ bool
df.describe(include=['object',bool])
# Out:
#        State International plan Voice mail plan  Churn
# count    667                667             667    667
# unique    51                  2               2      2
# top       AZ                 No              No  False
# freq      19                614             478    572

# %%
#นับจำนวนข้อมูล Churn ในแต่ละค่า
df['Churn'].value_counts()
# Out:
# False    572
# True      95
# Name: Churn, dtype: int64

# %%
#นับจำนวนข้อมูล International plan ในแต่ละค่า
df['International plan'].value_counts()
# Out:
# No     614
# Yes     53
# Name: International plan, dtype: int64

# %%
#ลองทำเอง นับจำนวนข้อมูลแบ่งตาม Voice mail plan
df['Voice mail plan'].value_counts()
# Out:
# No     478
# Yes    189
# Name: Voice mail plan, dtype: int64

# %%
#Summary tables
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan   No  Yes
# Churn
# False               538   34
# True                 76   19

# %%
#ลองทำเอง ดูจำนวนคน แยกตาม Churn และ แยกตาม State
pd.crosstab(df['Churn'], df['State'])
# Out:
# State  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL  ...  SD  TN  TX  UT  VA  VT  \
# Churn                                          ...
# False   9  13   8  18   6   5  14   9   9   8  ...   9  12  15  10   9  14
# True    0   1   0   1   4   2   1   0   1   1  ...   2   0   2   2   1   2
#
# State  WA  WI  WV  WY
# Churn
# False  14  14  15  10
# True    4   3   3   1
#
# [2 rows x 51 columns]

# %%
#นับค่า Null
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
#pivot table
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'],
               ['Area code'], aggfunc='mean')
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408              99.390533       100.680473         100.952663
# 415             101.928783       100.074184          99.023739
# 510             100.484472       101.105590         101.515528

# %%
#ลองทำเอง สร้าง Pivot Table 'Total day calls', 'Total eve calls', 'Total night calls'
#แบ่งตาม Churn
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'],
               ['Churn'], aggfunc='mean')
# Out:
#        Total day calls  Total eve calls  Total night calls
# Churn
# False       100.776224       100.047203         100.258741
# True        101.905263       103.063158          99.242105

# %% [markdown]
# #3) ลบคอลัมน์ที่ไม่ต้องการทิ้ง

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#ลบคอลัมน์ State
df.drop(columns= ['State'], inplace=True)
df.columns
# Out:
# Index(['Account length', 'Area code', 'International plan', 'Voice mail plan',
#        'Number vmail messages', 'Total day minutes', 'Total day calls',
#        'Total day charge', 'Total eve minutes', 'Total eve calls',
#        'Total eve charge', 'Total night minutes', 'Total night calls',
#        'Total night charge', 'Total intl minutes', 'Total intl calls',
#        'Total intl charge', 'Customer service calls', 'Churn'],
#       dtype='object')

# %% [markdown]
# #4) Data Visualization

# %%
#Bar Plot
#Appropriate for lots of values in a categorical variable or discrete numeric variable

sns.countplot(x="Area code", data=df)
plt.title('Number of customers');

# %%
#Comparation (Churn)

sns.countplot(x="Area code", hue='Churn', data=df)
plt.title('Number of customers');

# %%
#ลองทำเอง
#กราฟเปรียบเทียบจำนวนลูกค้าที่ Churn กับ Voice mail plan
sns.countplot(x="Churn", hue='Voice mail plan', data=df)
plt.title('Number of customers');

# %%
#กราฟเปรียบเทียบจำนวนลูกค้าที่ Churn กับ International plan
sns.countplot(x="Churn", hue='International plan', data=df)
plt.title('Number of customers');

# %%
# boxplot ของ Total day minutes
sns.boxplot(df['Total day minutes'])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Account length', 'Area code', 'International plan', 'Voice mail plan',
#        'Number vmail messages', 'Total day minutes', 'Total day calls',
#        'Total day charge', 'Total eve minutes', 'Total eve calls',
#        'Total eve charge', 'Total night minutes', 'Total night calls',
#        'Total night charge', 'Total intl minutes', 'Total intl calls',
#        'Total intl charge', 'Customer service calls', 'Churn'],
#       dtype='object')

# %%
cols = ['Total day minutes','Total night minutes','Total eve minutes']

# %%
# boxplot ของ cols -using PANDAS
df[cols].plot.box()
# Out:
# <Axes: >

# %%
sns.boxplot([df['Total day minutes'], df['Total eve minutes'], df['Total night minutes']])
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Account length'}>,
#         <Axes: title={'center': 'Area code'}>,
#         <Axes: title={'center': 'Number vmail messages'}>,
#         <Axes: title={'center': 'Total day minutes'}>],
#        [<Axes: title={'center': 'Total day calls'}>,
#         <Axes: title={'center': 'Total day charge'}>,
#         <Axes: title={'center': 'Total eve minutes'}>,
#         <Axes: title={'center': 'Total eve calls'}>],
#        [<Axes: title={'center': 'Total eve charge'}>,
#         <Axes: title={'center': 'Total night minutes'}>,
#         <Axes: title={'center': 'Total night calls'}>,
#         <Axes: title={'center': 'Total night charge'}>],
#        [<Axes: title={'center': 'Total intl minutes'}>,
#         <Axes: title={'center': 'Total intl calls'}>,
#         <Axes: title={'center': 'Total intl charge'}>,
#         <Axes: title={'center': 'Customer service calls'}>]], dtype=object)

# %%
#Histogram ของ Total night minutes
df['Total night minutes'].hist()
# Out:
# <Axes: >

# %%
#Histogram ของ Total day minutes
df['Total day minutes'].hist()
# Out:
# <Axes: >

# %%
#Histogram ของ Total eve minutes
df['Total eve minutes'].hist()
# Out:
# <Axes: >

# %%
df[cols].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#เปรียบเทียบจำนวนนาทีการโทรในช่วงกลางวัน ตอนเย็น และกลางคืน
plt.figure(figsize=(12,6))
sns.distplot( df["Total day minutes"] , color="skyblue",label="Day")
sns.distplot( df["Total eve minutes"] , color="green",label="Evening")
sns.distplot( df["Total night minutes"] , color="orange",label="night")
plt.legend();
# Out:
# <ipython-input-54-1aea9457587b>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df["Total day minutes"] , color="skyblue",label="Day")
# <ipython-input-54-1aea9457587b>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df["Total eve minutes"] , color="green",label="Evening")
# <ipython-input-54-1aea9457587b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df["Total night minutes"] , color="orange",label="night")

# %%
#แบ่งข้อมูลออกเป็น 2 กลุ่ม
df_not_churn=df[df["Churn"]==False]
df_churn=df[df["Churn"]==True]

# %%
#Distribution of Total day minutes, comparing churn and not churn
plt.figure(figsize=(12,6))
sns.distplot( df_not_churn["Total day minutes"] , color="skyblue",label="Not Churn")
sns.distplot( df_churn["Total day minutes"] , color="red",label="Churn")
plt.legend();
# Out:
# <ipython-input-56-9a0c1c4961c8>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_churn["Total day minutes"] , color="skyblue",label="Not Churn")
# <ipython-input-56-9a0c1c4961c8>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_churn["Total day minutes"] , color="red",label="Churn")

# %%
#Distribution of Total eve minutes, comparing churn and not churn
plt.figure(figsize=(12,6))
sns.distplot( df_not_churn["Total eve minutes"] , color="skyblue",label="Not Churn")
sns.distplot( df_churn["Total eve minutes"] , color="red",label="Churn")
plt.legend();
# Out:
# <ipython-input-57-4b087b2dd0d2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_churn["Total eve minutes"] , color="skyblue",label="Not Churn")
# <ipython-input-57-4b087b2dd0d2>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_churn["Total eve minutes"] , color="red",label="Churn")

# %%
#Distribution of Total night minutes, comparing churn and not churn
plt.figure(figsize=(12,6))
sns.distplot( df_not_churn["Total night minutes"] , color="skyblue",label="Not Churn")
sns.distplot( df_churn["Total night minutes"] , color="red",label="Churn")
plt.legend();
# Out:
# <ipython-input-58-d743407be0e2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_churn["Total night minutes"] , color="skyblue",label="Not Churn")
# <ipython-input-58-d743407be0e2>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_churn["Total night minutes"] , color="red",label="Churn")

# %% [markdown]
# ##Exercise
# **แล้วถ้าอยากรู้ว่าลูกค้าที่เป็น Internation Plan มีลักษณะการโทรต่างกับลูกค้าธรรมดาอย่างไร จะ Plot อย่างไรดี ???**

# %%
#สร้าง Data Frame แยก Internationa plan กับธรรมดา
#แบ่งข้อมูลออกเป็น 2 กลุ่ม
df_not_inter=df[df["International plan"]=="No"]
df_inter=df[df["International plan"]=="Yes"]

# %%
#Distribution of Total day minutes, comparing by International plan
plt.figure(figsize=(12,6))
sns.distplot( df_inter["Total day minutes"] , color="green",label="International Plan")
sns.distplot( df_not_inter["Total day minutes"]  , color="red",label="Orninary Plan")
plt.legend();
# Out:
# <ipython-input-62-61ca61ee1917>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_inter["Total day minutes"] , color="green",label="International Plan")
# <ipython-input-62-61ca61ee1917>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_inter["Total day minutes"]  , color="red",label="Orninary Plan")

# %%
#Distribution of Total eve minutes, comparing by International plan
plt.figure(figsize=(12,6))
sns.distplot( df_inter["Total eve minutes"] , color="green",label="International Plan")
sns.distplot( df_not_inter["Total eve minutes"]  , color="red",label="Not International Plan")
plt.legend();
# Out:
# <ipython-input-67-1f321fcdc283>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_inter["Total eve minutes"] , color="green",label="International Plan")
# <ipython-input-67-1f321fcdc283>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_inter["Total eve minutes"]  , color="red",label="Not International Plan")

# %%
#Distribution of Total night minutes, comparing by International plan
plt.figure(figsize=(12,6))
sns.distplot( df_inter["Total night minutes"] , color="green",label="International Plan")
sns.distplot( df_not_inter["Total night minutes"]  , color="red",label="Not International Plan")
plt.legend();
# Out:
# <ipython-input-66-fe2657b48ad6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_inter["Total night minutes"] , color="green",label="International Plan")
# <ipython-input-66-fe2657b48ad6>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df_not_inter["Total night minutes"]  , color="red",label="Not International Plan")
